# %%
import pandas as pd

# %% [markdown]
# ### Read the data from csv file :

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %% [markdown]
# Shape is the attribute which provides the dimension details (rows x columns)

# %%
df.shape
# Out:
# (88883, 85)

# %% [markdown]
# info()- Object which provides the datatypes, dimensions

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %% [markdown]
# When the option is set to display.max_colums with n, then it displays the columns for the limit set(n)

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %% [markdown]
# Provides the description of each column in the survey_results_public.csv

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %% [markdown]
# In case you need to just see `first` few rows and not all entries ? - use `df.head()` and in case of viewing certain nembers of rows, it ca be specified like `df.head(10)`

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %% [markdown]
# In case you need to just see `last` few rows and not all entries ? - use `df.tail()` and in case of viewing certain nembers of rows, it ca be specified like `df.tail(10)`

# %%
df.tail(5)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %% [markdown]
# ### Dataframe and Series Basics - Selecting Rows and Columns

# %% [markdown]
# Assuming or corelating the dataframe in a very pythonic way

# %%
people = {
    "first" : ['Danusha', 'Jane', 'Connor'],
    "second" : ['Shankar', 'Doe', 'Walsh'],
    "email" : ['DanushaShankar@gmail.com', 'JaneDoe@gmail.com', 'ConnorWalsh@gmail.com']
}

# %%
df_py = pd.DataFrame(people)

# %%
df_py
# Out:
#      first   second                     email
# 0  Danusha  Shankar  DanushaShankar@gmail.com
# 1     Jane      Doe         JaneDoe@gmail.com
# 2   Connor    Walsh     ConnorWalsh@gmail.com

# %% [markdown]
# Yeah bro, it worked, So this is exactly how it works

# %% [markdown]
# Lets try accessing a single column of my data frame

# %%
people['email']
# Out:
# ['DanushaShankar@gmail.com', 'JaneDoe@gmail.com', 'ConnorWalsh@gmail.com']

# %%
df_py['email']
# Out:
# 0    DanushaShankar@gmail.com
# 1           JaneDoe@gmail.com
# 2       ConnorWalsh@gmail.com
# Name: email, dtype: object

# %%
df_py.email
# Out:
# 0    DanushaShankar@gmail.com
# 1           JaneDoe@gmail.com
# 2       ConnorWalsh@gmail.com
# Name: email, dtype: object

# %%
type(df_py['email'])
# Out:
# pandas.core.series.Series

# %%
df_py['email'][0]
# Out:
# 'DanushaShankar@gmail.com'

# %% [markdown]
# ### Access multiple columns

# %%
df_py[['first', 'email']]
# Out:
#      first                     email
# 0  Danusha  DanushaShankar@gmail.com
# 1     Jane         JaneDoe@gmail.com
# 2   Connor     ConnorWalsh@gmail.com

# %%
df_py.columns
# Out:
# Index(['first', 'second', 'email'], dtype='object')

# %% [markdown]
# ### Is there a way to access the row ??

# %%
df_py.iloc[0]
# Out:
# first                      Danusha
# second                     Shankar
# email     DanushaShankar@gmail.com
# Name: 0, dtype: object

# %% [markdown]
# It is returning first row in the above example

# %% [markdown]
# ### Select multiple rows

# %%
df_py.iloc[[0, 1]]
# Out:
#      first   second                     email
# 0  Danusha  Shankar  DanushaShankar@gmail.com
# 1     Jane      Doe         JaneDoe@gmail.com

# %%
df_py.iloc[[0, 1], 2]
# Out:
# 0    DanushaShankar@gmail.com
# 1           JaneDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# #### With iloc we are searching by index, but using loc we can search using the label

# %%
df_py.loc[0]
# Out:
# first                      Danusha
# second                     Shankar
# email     DanushaShankar@gmail.com
# Name: 0, dtype: object

# %%
df_py.loc[[0, 1]]
# Out:
#      first   second                     email
# 0  Danusha  Shankar  DanushaShankar@gmail.com
# 1     Jane      Doe         JaneDoe@gmail.com

# %%
df_py.loc[[0, 1], 'email']
# Out:
# 0    DanushaShankar@gmail.com
# 1           JaneDoe@gmail.com
# Name: email, dtype: object

# %%
df_py.loc[[0, 1], ['email','first']]
# Out:
#                       email    first
# 0  DanushaShankar@gmail.com  Danusha
# 1         JaneDoe@gmail.com     Jane

# %% [markdown]
# ##### Lets start experimenting the same concept on our original data fetched from the stackoverflow..................

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %% [markdown]
# ##### Lets try adding value filter like we use to do in excel sheets

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[0]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
df.loc[[0, 1, 2], 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0 : 5, 'Hobbyist'] #Will slicing work actually ? - No braces btw
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# 5    Yes
# Name: Hobbyist, dtype: object

# %% [markdown]
# ##### We can try slicing the columns also

# %%
df.loc[0 : 5, 'Hobbyist': 'Employment']
# Out:
#   Hobbyist                 OpenSourcer  \
# 0      Yes                       Never
# 1       No     Less than once per year
# 2      Yes                       Never
# 3       No                       Never
# 4      Yes  Once a month or more often
# 5      Yes                       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
# 5  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time
# 3                      Employed full-time
# 4                      Employed full-time
# 5                      Employed full-time

# %% [markdown]
# ### Indexes - How to Set, Reset, and Use Indexes

# %%
 df_py
# Out:
#      first   second                     email
# 0  Danusha  Shankar  DanushaShankar@gmail.com
# 1     Jane      Doe         JaneDoe@gmail.com
# 2   Connor    Walsh     ConnorWalsh@gmail.com

# %%
df_py['email']
# Out:
# 0    DanushaShankar@gmail.com
# 1           JaneDoe@gmail.com
# 2       ConnorWalsh@gmail.com
# Name: email, dtype: object

# %% [markdown]
# Setting the index as email, temporarly for single time

# %%
 df_py.set_index('email')
# Out:
#                             first   second
# email
# DanushaShankar@gmail.com  Danusha  Shankar
# JaneDoe@gmail.com            Jane      Doe
# ConnorWalsh@gmail.com      Connor    Walsh

# %% [markdown]
# Lets try setting it inplace, i.e in the actual df_pf

# %%
 df_py.set_index('email', inplace=True)

# %%
 df_py
# Out:
#                             first   second
# email
# DanushaShankar@gmail.com  Danusha  Shankar
# JaneDoe@gmail.com            Jane      Doe
# ConnorWalsh@gmail.com      Connor    Walsh

# %%
df_py.index
# Out:
# Index(['DanushaShankar@gmail.com', 'JaneDoe@gmail.com',
#        'ConnorWalsh@gmail.com'],
#       dtype='object', name='email')

# %%
df_py.loc['DanushaShankar@gmail.com']
# Out:
# first     Danusha
# second    Shankar
# Name: DanushaShankar@gmail.com, dtype: object

# %%
df_py.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-5849957e8a17> in <module>
# ----> 1 df_py.loc[0]
#
# ...

# %%
df_py.iloc[0] #Works with iloc
# Out:
# first     Danusha
# second    Shankar
# Name: DanushaShankar@gmail.com, dtype: object

# %% [markdown]
# #### To reset the index

# %%
df_py.reset_index(inplace=True)

# %%
df_py
# Out:
#                       email    first   second
# 0  DanushaShankar@gmail.com  Danusha  Shankar
# 1         JaneDoe@gmail.com     Jane      Doe
# 2     ConnorWalsh@gmail.com   Connor    Walsh

# %% [markdown]
# ### Back to stackoverflow example..........

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %% [markdown]
# ## Alright i feel not so comfortable having the default index and actual index of csv, lets get it removed by setting index

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')

# %%
df.head(5)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %% [markdown]
# ##### Boom!!!!!!!!! It actually worked

# %%
df.loc[1]
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# ...

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
schema_df.set_index('Column', inplace=True)

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_df.loc['MgrIdiot']
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
schema_df.loc['MgrIdiot', 'QuestionText'] #Row and corresponding column
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %% [markdown]
# #### Is it possible to sort Alphabetically ?????????

# %%
schema_df.sort_index()
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %%
schema_df.sort_index(inplace=True) #Sort permenantly

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %% [markdown]
# ## Filtering - Using Conditionals to filter Rows and columns

# %%
df_py
# Out:
#                       email    first   second
# 0  DanushaShankar@gmail.com  Danusha  Shankar
# 1         JaneDoe@gmail.com     Jane      Doe
# 2     ConnorWalsh@gmail.com   Connor    Walsh

# %% [markdown]
# Check if the second name is Doe

# %%
df_py['second'] == 'Doe'
# Out:
# 0    False
# 1     True
# 2    False
# Name: second, dtype: bool

# %%
filt = (df_py['second'] == 'Doe')

# %%
df_py[filt] #Applying the filter or simply to say conditional filter
# Out:
#                email first second
# 1  JaneDoe@gmail.com  Jane    Doe

# %%
df_py.loc[filt] #Apply the filter i.e passing the series
# Out:
#                email first second
# 1  JaneDoe@gmail.com  Jane    Doe

# %%
df_py.loc[filt, 'email'] #Email of lastname = Doe
# Out:
# 1    JaneDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# ### Filter using and or...

# %%
filt = (df_py['second'] == 'Doe') & (df_py['first'] == 'Jane')

# %%
df_py.loc[filt]
# Out:
#                email first second
# 1  JaneDoe@gmail.com  Jane    Doe

# %%
filt = (df_py['second'] == 'Doe') | (df_py['first'] == 'Danusha')

# %%
df_py.loc[filt]
# Out:
#                       email    first   second
# 0  DanushaShankar@gmail.com  Danusha  Shankar
# 1         JaneDoe@gmail.com     Jane      Doe

# %% [markdown]
# ### Lets try getting the complete opposite of the filter

# %%
df_py.loc[~filt]
# Out:
#                    email   first second
# 2  ConnorWalsh@gmail.com  Connor  Walsh

# %% [markdown]
# ## Back to real world example.....

# %%
df.head(5)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %% [markdown]
# ## Filter based on Salary

# %%
high_salary = (df['ConvertedComp'] > 70000)

# %%
df.loc[high_salary, ['Country', 'Age', 'ConvertedComp']]
# Out:
#                    Country   Age  ConvertedComp
# Respondent
# 6                   Canada  28.0       366420.0
# 9              New Zealand  23.0        95179.0
# 13           United States  28.0        90000.0
# 16          United Kingdom  26.0       455352.0
# 22           United States  47.0       103000.0
# ...                    ...   ...            ...
# 88876        United States  23.0       180000.0
# 88877        United States  48.0      2000000.0
# 88878        United States  26.0       130000.0
# 88879              Finland  34.0        82488.0
# 88882          Netherlands   NaN       588012.0
#
# [22289 rows x 3 columns]

# %%
countries = ['United States', 'United Kingdom', 'India', 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt , ['Country', 'Age', 'ConvertedComp']]
# Out:
#                    Country   Age  ConvertedComp
# Respondent
# 1           United Kingdom  14.0            NaN
# 4            United States  22.0        61000.0
# 6                   Canada  28.0       366420.0
# 8                    India  24.0            NaN
# 10                   India   NaN        13293.0
# ...                    ...   ...            ...
# 85642        United States  34.0            NaN
# 85961       United Kingdom  45.0            NaN
# 86012                India  24.0            NaN
# 88282        United States   NaN            NaN
# 88377               Canada   NaN            NaN
#
# [39142 rows x 3 columns]

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %% [markdown]
#  ## Updating Rows and Columns - Modifying Data Within DataFrames

# %%
df_py
# Out:
#                       email    first   second
# 0  DanushaShankar@gmail.com  Danusha  Shankar
# 1         JaneDoe@gmail.com     Jane      Doe
# 2     ConnorWalsh@gmail.com   Connor    Walsh

# %%
df_py.columns
# Out:
# Index(['email', 'first', 'second'], dtype='object')

# %% [markdown]
# ### Rename the column names

# %%
df_py.columns = ['email', 'last_name', 'first_name']

# %%
df_py
# Out:
#                       email last_name           first_name
# 0  DanushaShankar@gmail.com   Danusha              Shankar
# 1         JaneDoe@gmail.com      Jane                  Doe
# 2                      John     walsh  Johnwalsh@gmail.com

# %% [markdown]
# Lets say i need to convert the column to upper column

# %%
df_py.columns = [x.upper() for x in df_py.columns]

# %%
df_py
# Out:
#                       EMAIL LAST_NAME           FIRST_NAME
# 0  DanushaShankar@gmail.com   Danusha              Shankar
# 1         JaneDoe@gmail.com      Jane                  Doe
# 2                      John     walsh  Johnwalsh@gmail.com

# %%
df_py.columns = df_py.columns.str.replace('_', ' ')

# %%
df_py
# Out:
#                       EMAIL LAST NAME           FIRST NAME
# 0  DanushaShankar@gmail.com   Danusha              Shankar
# 1         JaneDoe@gmail.com      Jane                  Doe
# 2                      John     walsh  Johnwalsh@gmail.com

# %%
df_py.columns = df_py.columns.str.replace(' ', '_')

# %%
df_py.columns = [x.lower() for x in df_py.columns]

# %%
df_py
# Out:
#                       email last_name           first_name
# 0  DanushaShankar@gmail.com   Danusha              Shankar
# 1         JaneDoe@gmail.com      Jane                  Doe
# 2                      John     walsh  Johnwalsh@gmail.com

# %%
df_py.rename(columns= {"first_name": "first", "last_name" : "last"}, inplace=True)

# %%
df_py
# Out:
#                       email     last                first
# 0  DanushaShankar@gmail.com  Danusha              Shankar
# 1         JaneDoe@gmail.com     Jane                  Doe
# 2                      John    walsh  Johnwalsh@gmail.com

# %% [markdown]
# That's quiet a good revert :)

# %%
df_py.loc[2] # the 3rd row
# Out:
# email                   John
# last                   walsh
# first    Johnwalsh@gmail.com
# Name: 2, dtype: object

# %%
df_py.loc[2] = ["John", "smith", "johnsmith@gmail.com"]

# %%
df_py
# Out:
#                       email     last                first
# 0  DanushaShankar@gmail.com  Danusha              Shankar
# 1         JaneDoe@gmail.com     Jane                  Doe
# 2                      John    smith  johnsmith@gmail.com

# %%
df_py.loc[2, ['last', 'email']]
# Out:
# last     smith
# email     John
# Name: 2, dtype: object

# %%
df_py.loc[2, ['last', 'email']] = ["walsh", "Johnwalsh@gmail.com"]

# %%
df_py
# Out:
#                       email     last                first
# 0  DanushaShankar@gmail.com  Danusha              Shankar
# 1         JaneDoe@gmail.com     Jane                  Doe
# 2       Johnwalsh@gmail.com    walsh  johnsmith@gmail.com

# %%
df_py.loc[2, 'last'] = 'smith'

# %%
df_py
# Out:
#                       email     last                first
# 0  DanushaShankar@gmail.com  Danusha              Shankar
# 1         JaneDoe@gmail.com     Jane                  Doe
# 2       Johnwalsh@gmail.com    smith  johnsmith@gmail.com

# %%
df_py.at[2, 'last'] = 'walsh'

# %%
df_py.at[2, 'first'] = 'john'

# %%
df_py
# Out:
#                       email     last    first
# 0  DanushaShankar@gmail.com  Danusha  Shankar
# 1         JaneDoe@gmail.com     Jane      Doe
# 2       Johnwalsh@gmail.com    walsh     john

# %%
filt = (df_py['email'] == 'Johnwalsh@gmail.com')
df_py[filt]
# Out:
#                  email   last first
# 2  Johnwalsh@gmail.com  walsh  john

# %%
df_py[filt]['last']
# Out:
# 2    walsh
# Name: last, dtype: object

# %%
df_py[filt]['last'] = 'xx'
# Out:
# <ipython-input-208-e85a341cba5c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_py[filt]['last'] = 'xx'

# %% [markdown]
# uhhh....that's exactly not possible...... (:

# %%
df_py
# Out:
#                       email     last    first
# 0  DanushaShankar@gmail.com  Danusha  Shankar
# 1         JaneDoe@gmail.com     Jane      Doe
# 2       Johnwalsh@gmail.com    walsh     john

# %%
df_py.loc[filt,'last'] = 'Gebbins'

# %%
df_py
# Out:
#                       email     last    first
# 0  DanushaShankar@gmail.com  Danusha  Shankar
# 1         JaneDoe@gmail.com     Jane      Doe
# 2       Johnwalsh@gmail.com  Gebbins     john

# %% [markdown]
# ##### Still now we are wating how to assign or change single row of data, lets see the same for multiple rows

# %%
df_py['email'].str.lower() #Just displays the change
# Out:
# 0    danushashankar@gmail.com
# 1           janedoe@gmail.com
# 2         johnwalsh@gmail.com
# Name: email, dtype: object

# %%
df_py
# Out:
#                       email     last    first
# 0  DanushaShankar@gmail.com  Danusha  Shankar
# 1         JaneDoe@gmail.com     Jane      Doe
# 2       Johnwalsh@gmail.com  Gebbins     john

# %%
df_py['email'] = df_py['email'].str.lower() #for implying the change

# %%
df_py
# Out:
#                       email     last    first
# 0  danushashankar@gmail.com  Danusha  Shankar
# 1         janedoe@gmail.com     Jane      Doe
# 2       johnwalsh@gmail.com  Gebbins     john

# %% [markdown]
# Lets try on the following methods:
# apply
# map
# applymap
# replace

# %%
df_py['email'].apply(len)
# Out:
# 0    24
# 1    17
# 2    19
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df_py['email'].apply(update_email)
# Out:
# 0    DANUSHASHANKAR@GMAIL.COM
# 1           JANEDOE@GMAIL.COM
# 2         JOHNWALSH@GMAIL.COM
# Name: email, dtype: object

# %%
df_py
# Out:
#                       email     last    first
# 0  danushashankar@gmail.com  Danusha  Shankar
# 1         janedoe@gmail.com     Jane      Doe
# 2       johnwalsh@gmail.com  Gebbins     john

# %%
df_py['email'] = df_py['email'].apply(update_email)

# %%
df_py
# Out:
#                       email     last    first
# 0  DANUSHASHANKAR@GMAIL.COM  Danusha  Shankar
# 1         JANEDOE@GMAIL.COM     Jane      Doe
# 2       JOHNWALSH@GMAIL.COM  Gebbins     john

# %%
df_py['email'] = df_py['email'].apply(lambda x: x.lower())

# %%
df_py
# Out:
#                       email     last    first
# 0  danushashankar@gmail.com  Danusha  Shankar
# 1         janedoe@gmail.com     Jane      Doe
# 2       johnwalsh@gmail.com  Gebbins     john

# %%
df_py['email'].apply(len)
# Out:
# 0    24
# 1    17
# 2    19
# Name: email, dtype: int64

# %%
df_py.apply(len) # it is applying the len to series but not all the values
# Out:
# email    3
# last     3
# first    3
# dtype: int64

# %%
len(df_py['email'])
# Out:
# 3

# %%
df_py.apply(len, axis='columns') #By default it counts the rows
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df_py.apply(pd.Series.min) #Consider validating numerals as we have strings here it returns the alphabetical
# Out:
# email    danushashankar@gmail.com
# last                      Danusha
# first                         Doe
# dtype: object

# %%
df_py.apply(lambda x: x.min()) #it is the same
# Out:
# email    danushashankar@gmail.com
# last                      Danusha
# first                         Doe
# dtype: object

# %%
df_py.applymap(len)
# Out:
#    email  last  first
# 0     24     7      7
# 1     17     4      3
# 2     19     7      4

# %% [markdown]
# applymap is applying the method to all the elements in the datafram wheras apply will do it for series alone

# %%
df_py.applymap(str.lower)
# Out:
#                       email     last    first
# 0  danushashankar@gmail.com  danusha  shankar
# 1         janedoe@gmail.com     jane      doe
# 2       johnwalsh@gmail.com  gebbins     john

# %% [markdown]
# ##### map : substitutes the elements in the series

# %%
df_py['first'].map({'Shankar' : 'Venkat'}) #Value which we didn't convert is assigned to Nan
# Out:
# 0    Venkat
# 1       NaN
# 2       NaN
# Name: first, dtype: object

# %%
df_py['first'].replace({'Shankar' : 'Venkat'})
# Out:
# 0    Venkat
# 1       Doe
# 2      john
# Name: first, dtype: object

# %%
df_py['first'] = df_py['first'].replace({'Shankar' : 'Venkat'})

# %%
df_py
# Out:
#                       email     last   first
# 0  danushashankar@gmail.com  Danusha  Venkat
# 1         janedoe@gmail.com     Jane     Doe
# 2       johnwalsh@gmail.com  Gebbins    john

# %%
df.rename(columns = {'ConvertedComp':'SalaryUSD'}, inplace=True)

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].replace({'Yes' : True, 'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist'] = df['Hobbyist'].replace({'Yes' : True, 'No': False})

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %% [markdown]
# ## Add/Remove Rows and Columns From DataFrames

# %%
df_py
# Out:
#                       email     last   first
# 0  danushashankar@gmail.com  Danusha  Venkat
# 1         janedoe@gmail.com     Jane     Doe
# 2       johnwalsh@gmail.com  Gebbins    john

# %% [markdown]
# ## Merge columns

# %%
df_py['first'] + ' ' + df_py['last']
# Out:
# 0    Venkat Danusha
# 1          Doe Jane
# 2      john Gebbins
# dtype: object

# %%
df_py['full_name'] = df_py['first'] + ' ' + df_py['last'] #Adding a new column

# %%
df_py
# Out:
#                       email     last   first       full_name
# 0  danushashankar@gmail.com  Danusha  Venkat  Venkat Danusha
# 1         janedoe@gmail.com     Jane     Doe        Doe Jane
# 2       johnwalsh@gmail.com  Gebbins    john    john Gebbins

# %% [markdown]
# Lets try Removing a column

# %%
df_py.drop(columns=['first', 'last'], inplace=True)

# %%
df_py
# Out:
#                       email       full_name
# 0  danushashankar@gmail.com  Venkat Danusha
# 1         janedoe@gmail.com        Doe Jane
# 2       johnwalsh@gmail.com    john Gebbins

# %%
df_py['full_name'].str.split(" ", expand=True)
# Out:
#         0        1
# 0  Venkat  Danusha
# 1     Doe     Jane
# 2    john  Gebbins

# %%
df_py[['last', 'first']] = df_py['full_name'].str.split(" ", expand=True)

# %%
df_py
# Out:
#                       email       full_name    last    first
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins

# %% [markdown]
# Lets try append or adding one df with another

# %%
df_py.append({'first': 'Tony'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-277-e0c8ac603beb> in <module>
# ----> 1 df_py.append({'first': 'Tony'})
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    7943             if isinstance(other, dict):
#    7944                 if not ignore_index:
# -> 7945                     raise TypeError("Can only append a dict if ignore_index=True")
#    7946                 other = Series(other)
#    7947             if other.name is None and not ignore_index:
#
# TypeError: Can only append a dict if ignore_index=True

# %%
df_py.append({'first': 'Tony'}, ignore_index=True)
# Out:
#                       email       full_name    last    first
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins
# 3                       NaN             NaN     NaN     Tony

# %%
people = {
    "first" : ['Tony', 'Steve'],
    "last" : ['Stark', 'Rogers'],
    "email" : ['Ironman@avenger.com', 'Cap@avenger.com']
}
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first    last                email
# 0   Tony   Stark  Ironman@avenger.com
# 1  Steve  Rogers      Cap@avenger.com

# %% [markdown]
# Lets try appending df_py and df2

# %%
df_py.append(df2, ignore_index=True)
# Out:
#                       email       full_name    last    first
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins
# 3       Ironman@avenger.com             NaN   Stark     Tony
# 4           Cap@avenger.com             NaN  Rogers    Steve

# %%
df_py = df_py.append(df2, ignore_index=True)

# %%
df_py
# Out:
#                       email       full_name    last    first
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins
# 3       Ironman@avenger.com             NaN   Stark     Tony
# 4           Cap@avenger.com             NaN  Rogers    Steve

# %%
df_py.drop(index=4) #Delete Captain America :)
# Out:
#                       email       full_name    last    first
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins
# 3       Ironman@avenger.com             NaN   Stark     Tony

# %%
filt = df_py['last']=='Doe'
df_py.drop(index=df_py[filt].index)
# Out:
#                       email       full_name    last    first
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins
# 3       Ironman@avenger.com             NaN   Stark     Tony
# 4           Cap@avenger.com             NaN  Rogers    Steve

# %% [markdown]
# ## Sorting Data in pandas

# %%
df_py
# Out:
#                       email       full_name    last    first
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins
# 3       Ironman@avenger.com             NaN   Stark     Tony
# 4           Cap@avenger.com             NaN  Rogers    Steve

# %% [markdown]
# How abt sorting it based on last name

# %%
df_py.sort_values(by='last')
# Out:
#                       email       full_name    last    first
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane
# 4           Cap@avenger.com             NaN  Rogers    Steve
# 3       Ironman@avenger.com             NaN   Stark     Tony
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins

# %%
df_py.sort_values(by='last', ascending=False)
# Out:
#                       email       full_name    last    first
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha
# 3       Ironman@avenger.com             NaN   Stark     Tony
# 4           Cap@avenger.com             NaN  Rogers    Steve
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane

# %%
df_py.sort_values(by=['last', 'first'], ascending=False) #incase last name are same
# Out:
#                       email       full_name    last    first
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha
# 3       Ironman@avenger.com             NaN   Stark     Tony
# 4           Cap@avenger.com             NaN  Rogers    Steve
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane

# %%
df_py.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)

# %%
df_py
# Out:
#                       email       full_name    last    first
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha
# 3       Ironman@avenger.com             NaN   Stark     Tony
# 4           Cap@avenger.com             NaN  Rogers    Steve
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane

# %%
df_py.sort_index() #just reverting back
# Out:
#                       email       full_name    last    first
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins
# 3       Ironman@avenger.com             NaN   Stark     Tony
# 4           Cap@avenger.com             NaN  Rogers    Steve

# %%
df_py['last'].sort_values()
# Out:
# 1       Doe
# 4    Rogers
# 3     Stark
# 0    Venkat
# 2      john
# Name: last, dtype: object

# %%
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# ...                                                       ...       ...
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.sort_values(by='Country', inplace=True)

# %%
df['Country'].head(50)
# Out:
# Respondent
# 39258    Afghanistan
# 63129    Afghanistan
# 85715    Afghanistan
# 50767    Afghanistan
# 2782     Afghanistan
# 63019    Afghanistan
# 6417     Afghanistan
# 40000    Afghanistan
# 88731    Afghanistan
# 48436    Afghanistan
# 10746    Afghanistan
# 62525    Afghanistan
# 49702    Afghanistan
# 33178    Afghanistan
# 60946    Afghanistan
# 86362    Afghanistan
# 88582    Afghanistan
# 28638    Afghanistan
# 722      Afghanistan
# 26340    Afghanistan
# 86932    Afghanistan
# 85825    Afghanistan
# 7085     Afghanistan
# 7353     Afghanistan
# 87091    Afghanistan
# 58760    Afghanistan
# 74386    Afghanistan
# 29045    Afghanistan
# 51859    Afghanistan
# 45854    Afghanistan
# 47110    Afghanistan
# 44403    Afghanistan
# 22450    Afghanistan
# 8149     Afghanistan
# 80926    Afghanistan
# 59560    Afghanistan
# 60569    Afghanistan
# 37802    Afghanistan
# 29736    Afghanistan
# 43106    Afghanistan
# 12310    Afghanistan
# 58450    Afghanistan
# ...

# %%
df[['Country', 	'SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 39258       Afghanistan    19152.0
# 63129       Afghanistan  1000000.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN
# 63019       Afghanistan        NaN
# 6417        Afghanistan        NaN
# 40000       Afghanistan        NaN
# 88731       Afghanistan        NaN
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 62525       Afghanistan        NaN
# 49702       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 60946       Afghanistan        NaN
# 86362       Afghanistan        NaN
# 88582       Afghanistan        NaN
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 26340       Afghanistan        NaN
# 86932       Afghanistan        NaN
# 85825       Afghanistan        NaN
# 7085        Afghanistan    14364.0
# 7353        Afghanistan        NaN
# 87091       Afghanistan        NaN
# ...

# %%
df.sort_values(by=['Country','SalaryUSD'], ascending=[True, False], inplace=True)

# %%
df[['Country', 	'SalaryUSD']].head(50)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0
# 22450       Afghanistan     7980.0
# 48436       Afghanistan     4464.0
# 10746       Afghanistan     3996.0
# 8149        Afghanistan     1596.0
# 29736       Afghanistan     1116.0
# 28638       Afghanistan        0.0
# 722         Afghanistan        0.0
# 85715       Afghanistan        NaN
# 50767       Afghanistan        NaN
# 2782        Afghanistan        NaN
# 63019       Afghanistan        NaN
# 6417        Afghanistan        NaN
# 40000       Afghanistan        NaN
# 88731       Afghanistan        NaN
# 62525       Afghanistan        NaN
# 49702       Afghanistan        NaN
# 33178       Afghanistan        NaN
# 60946       Afghanistan        NaN
# 86362       Afghanistan        NaN
# 88582       Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10, 'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      True
# 87896                          I am a developer by profession      True
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 78151                          I am a developer by profession      True
# 80200                          I am a developer by profession      True
# 52132                          I am a developer by profession      True
# 75561                          I am a developer by profession      True
# 32250                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
df.nsmallest(10, 'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 28638                          I am a developer by profession      True
# 722                            I am a developer by profession     False
# 13825                          I am a developer by profession      True
# 40913                          I am a developer by profession      True
# 30630                          I am a developer by profession      True
# 69049                          I am a developer by profession     False
# 19340       I am not primarily a developer, but I write co...      True
# 16214       I am not primarily a developer, but I write co...      True
# 29355                          I am a developer by profession      True
# 1685                           I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 28638       Less than once a month but more than once per ...
# ...

# %% [markdown]
# ## Grouping and Aggregating - Analyzing and Exploring Your Data

# %% [markdown]
# ##### Lame Google search results for Aggregating : collect (related items of content) so as to display or link to them.

# %%
df['SalaryUSD'].head(15)
# Out:
# Respondent
# 63129    1000000.0
# 50499     153216.0
# 39258      19152.0
# 58450      17556.0
# 7085       14364.0
# 22450       7980.0
# 48436       4464.0
# 10746       3996.0
# 8149        1596.0
# 29736       1116.0
# 28638          0.0
# 722            0.0
# 85715          NaN
# 50767          NaN
# 2782           NaN
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].median()
# Out:
# 57287.0

# %% [markdown]
# ### Median:
# The median is the middle number in a sorted, ascending or descending, list of numbers and can be more descriptive of that data set than the average.

# %%
df.median()
# Out:
# Hobbyist           1.0
# CompTotal      62000.0
# SalaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df.describe() # the 50% is the median - average
# Out:
#           CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['SalaryUSD'].describe()
# Out:
# count    5.582300e+04
# mean     1.271107e+05
# std      2.841523e+05
# min      0.000000e+00
# 25%      2.577750e+04
# 50%      5.728700e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].count()
# Out:
# 55823

# %% [markdown]
# ### Count():
# It returns the count of value is present for the field(i.e 55823 people has provided the salary details)

# %%
df['SocialMedia']
# Out:
# Respondent
# 63129    I don't use social media
# 50499                    WhatsApp
# 39258                    Facebook
# 58450                    Facebook
# 7085                    Instagram
#                    ...
# 88062                         NaN
# 88076                         NaN
# 88601                         NaN
# 88802                         NaN
# 88816                         NaN
# Name: SocialMedia, Length: 88883, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True) #To get the data in percentage
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %% [markdown]
# ### Lets get started by grouping  :
# Spliting the option, Applying the function and combining the results......

# %%
df['Country'].value_counts()
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Timor-Leste                             1
# Saint Vincent and the Grenadines        1
# Niger                                   1
# Tonga                                   1
# Sao Tome and Principe                   1
# Name: Country, Length: 179, dtype: int64

# %%
country_grp = df.groupby(['Country']) #Contains the bunch of group as object

# %%
country_grp.get_group('India')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 80923                          I am a developer by profession      True
# 78265                          I am a developer by profession      True
# ...                                                       ...       ...
# 79312                  I am a student who is learning to code      True
# 79628                          I am a developer by profession     False
# 40151                                                     NaN     False
# 76400       I am not primarily a developer, but I write co...     False
# 30452                  I am a student who is learning to code     False
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt].head(5)
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 80923                          I am a developer by profession      True
# 78265                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 22013                                                   Never
# 28243                              Once a month or more often
# 72732       Less than once a month but more than once per ...
# 80923                              Once a month or more often
# 78265                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# ...

# %%
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# WeChat 微信                      5
# Hello                          5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
country_grp['SocialMedia'].value_counts().loc['India'] # it is the same result but instead we are not apply the filter
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['China'] #results in percentage
# Out:
# SocialMedia
# WeChat 微信                   0.670549
# YouTube                     0.088186
# Weibo 新浪微博                  0.069884
# I don't use social media    0.044925
# Twitter                     0.044925
# Reddit                      0.019967
# LinkedIn                    0.018303
# Facebook                    0.013311
# Instagram                   0.011647
# Youku Tudou 优酷              0.011647
# WhatsApp                    0.004992
# VK ВКонта́кте               0.001664
# Name: SocialMedia, dtype: float64

# %%
country_grp['SalaryUSD'].median().loc['Germany']
# Out:
# 63016.0

# %%
country_grp['SalaryUSD'].agg(['median', 'mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_grp['SalaryUSD'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum() #How many ppl knew python
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-372-39e646354acb> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
python_data = country_grp['LanguageWorkedWith'].apply(lambda x : x.str.contains('Python').sum())

# %%
python_data
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_data.loc['India']
# Out:
# 3105

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Timor-Leste                             1
# Saint Vincent and the Grenadines        1
# Niger                                   1
# Tonga                                   1
# Sao Tome and Principe                   1
# Name: Country, Length: 179, dtype: int64

# %%
python_data
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %% [markdown]
# ### Find how much percentage of ppl in each country knows python

# %%
python_df = pd.concat([country_respondents,python_data ], axis='columns')

# %%
python_df
# Out:
#                                   Country  LanguageWorkedWith
# United States                       20949               10083
# India                                9061                3105
# Germany                              5866                2451
# United Kingdom                       5737                2384
# Canada                               3395                1558
# ...                                   ...                 ...
# Timor-Leste                             1                   1
# Saint Vincent and the Grenadines        1                   0
# Niger                                   1                   1
# Tonga                                   1                   0
# Sao Tome and Principe                   1                   1
#
# [179 rows x 2 columns]

# %%
python_df.rename(inplace=True, columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'})

# %%
python_df
# Out:
#                                   NumRespondents  NumKnowsPython
# United States                              20949           10083
# India                                       9061            3105
# Germany                                     5866            2451
# United Kingdom                              5737            2384
# Canada                                      3395            1558
# ...                                          ...             ...
# Timor-Leste                                    1               1
# Saint Vincent and the Grenadines               1               0
# Niger                                          1               1
# Tonga                                          1               0
# Sao Tome and Principe                          1               1
#
# [179 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100

# %%
python_df
# Out:
#                                   NumRespondents  NumKnowsPython  \
# United States                              20949           10083
# India                                       9061            3105
# Germany                                     5866            2451
# United Kingdom                              5737            2384
# Canada                                      3395            1558
# ...                                          ...             ...
# Timor-Leste                                    1               1
# Saint Vincent and the Grenadines               1               0
# Niger                                          1               1
# Tonga                                          1               0
# Sao Tome and Principe                          1               1
#
#                                   PctKnowsPython
# United States                          48.131176
# India                                  34.267741
# ...

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.head(15)
# Out:
#                            NumRespondents  NumKnowsPython  PctKnowsPython
# Sao Tome and Principe                   1               1      100.000000
# Niger                                   1               1      100.000000
# Timor-Leste                             1               1      100.000000
# Dominica                                1               1      100.000000
# Turkmenistan                            7               6       85.714286
# Mauritania                              7               5       71.428571
# Guinea                                  3               2       66.666667
# Guyana                                  3               2       66.666667
# Bahamas                                 3               2       66.666667
# Uganda                                 72              47       65.277778
# Iceland                                49              30       61.224490
# Benin                                   5               3       60.000000
# ...

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    391.000000
# NumKnowsPython    182.000000
# PctKnowsPython     46.547315
# Name: Japan, dtype: float64

# %% [markdown]
# ## Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
df_py
# Out:
#                       email       full_name    last    first
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha
# 3       Ironman@avenger.com             NaN   Stark     Tony
# 4           Cap@avenger.com             NaN  Rogers    Steve
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane

# %%
df_py['age'] = ['33', '55', '63', 'missing', None]

# %%
df_py
# Out:
#                       email       full_name    last    first      age
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins       33
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha       55
# 3       Ironman@avenger.com             NaN   Stark     Tony       63
# 4           Cap@avenger.com             NaN  Rogers    Steve  missing
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane     None

# %%
df_py.dropna() #Remove the rows which has no data
# Out:
#                       email       full_name    last    first age
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins  33
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha  55

# %%
df_py.dropna(axis='index', how='any') #this and df_py.dropna() is same - Default arguments
# Out:
#                       email       full_name    last    first age
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins  33
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha  55

# %%
df_py.dropna(axis='index', how='all') #it means if all values is missing then remove
# Out:
#                       email       full_name    last    first      age
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins       33
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha       55
# 3       Ironman@avenger.com             NaN   Stark     Tony       63
# 4           Cap@avenger.com             NaN  Rogers    Steve  missing
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane     None

# %%
df_py.dropna(axis='columns', how='any')
# Out:
#                       email    last    first
# 2       johnwalsh@gmail.com    john  Gebbins
# 0  danushashankar@gmail.com  Venkat  Danusha
# 3       Ironman@avenger.com   Stark     Tony
# 4           Cap@avenger.com  Rogers    Steve
# 1         janedoe@gmail.com     Doe     Jane

# %%
df_py.dropna(axis='index', how='any', subset=['full_name'])
# Out:
#                       email       full_name    last    first   age
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins    33
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha    55
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane  None

# %% [markdown]
# In case if we have anyone of the values from email or last then removal can be ignored

# %%
df_py.dropna(axis='index', how='all', subset=['full_name', 'email'])
# Out:
#                       email       full_name    last    first      age
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins       33
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha       55
# 3       Ironman@avenger.com             NaN   Stark     Tony       63
# 4           Cap@avenger.com             NaN  Rogers    Steve  missing
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane     None

# %%
import numpy as np
df_py.replace('missing', np.nan, inplace=True)

# %%
df_py
# Out:
#                       email       full_name    last    first   age
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins    33
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha    55
# 3       Ironman@avenger.com             NaN   Stark     Tony    63
# 4           Cap@avenger.com             NaN  Rogers    Steve   NaN
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane  None

# %%
df_py.isna()
# Out:
#    email  full_name   last  first    age
# 2  False      False  False  False  False
# 0  False      False  False  False  False
# 3  False       True  False  False  False
# 4  False       True  False  False   True
# 1  False      False  False  False   True

# %%
df_py.fillna(0)
# Out:
#                       email       full_name    last    first age
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins  33
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha  55
# 3       Ironman@avenger.com               0   Stark     Tony  63
# 4           Cap@avenger.com               0  Rogers    Steve   0
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane   0

# %%
df_py.fillna("MISSING")
# Out:
#                       email       full_name    last    first      age
# 2       johnwalsh@gmail.com    john Gebbins    john  Gebbins       33
# 0  danushashankar@gmail.com  Venkat Danusha  Venkat  Danusha       55
# 3       Ironman@avenger.com         MISSING   Stark     Tony       63
# 4           Cap@avenger.com         MISSING  Rogers    Steve  MISSING
# 1         janedoe@gmail.com        Doe Jane     Doe     Jane  MISSING

# %% [markdown]
# ## Casting datatypes

# %%
df_py.dtypes
# Out:
# email        object
# full_name    object
# last         object
# first        object
# age          object
# dtype: object

# %%
df_py['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-433-3359bbaef447> in <module>
# ----> 1 df_py['age'].mean()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11116         )
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11118             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11119
#   11120         # pandas\core\generic.py:10924: error: Cannot assign to a method
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10724
#   10725     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10726         return self._stat_function(
# ...

# %% [markdown]
# ##### Duhhh, that is a str object

# %%
type(np.nan)
# Out:
# float

# %%
df_py['age'] = df_py['age'].astype(float)

# %%
 df_py['age'].mean()
# Out:
# 50.333333333333336

# %% [markdown]
# ##### Moving into Real time data framework -------------------->

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('data/survey_results_public.csv', na_values=na_vals)

# %%
df.head(5)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df['YearsCode'].head(10)
# Out:
# 0      4
# 1    NaN
# 2      3
# 3      3
# 4     16
# 5     13
# 6      6
# 7      8
# 8     12
# 9     12
# Name: YearsCode, dtype: object

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-457-14e5d2cf29c5> in <module>
# ----> 1 df['YearsCode'] = df['YearsCode'].astype(float)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %% [markdown]
# Seems there is a string which has unique values

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0 , inplace=True)

# %%
df['YearsCode'].replace('More than 50 years', 51 , inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', 51, '29',
#        '44', '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %%
df = pd.read_csv('data2/survey_results_public.csv')

# %%
df.head(5)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.loc[0, 'Date']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-467-88bae68786e5> in <module>
# ----> 1 df.loc[0, 'Date']
#
# ...

# %% [markdown]
# ## Reading/Writing Data to Different Sources - Excel, JSON, SQL, Etc

# %%
filt = (df['Country'] == 'India')
india_df = df.loc[filt]
india_df.head(5)
# Out:
#     Respondent                              MainBranch Hobbyist  \
# 7            8             I code primarily as a hobby      Yes
# 9           10          I am a developer by profession      Yes
# 14          15  I am a student who is learning to code      Yes
# 49          50          I am a developer by profession      Yes
# 64          65          I am a developer by profession      Yes
#
#                    OpenSourcer  \
# 7      Less than once per year
# 9   Once a month or more often
# 14                       Never
# 49  Once a month or more often
# 64                       Never
#
#                                            OpenSource  \
# 7   OSS is, on average, of HIGHER quality than pro...
# 9   OSS is, on average, of HIGHER quality than pro...
# 14  OSS is, on average, of HIGHER quality than pro...
# 49  OSS is, on average, of LOWER quality than prop...
# 64                                                NaN
#
# ...

# %%
india_df.to_csv('data/modified.csv')

# %%
india_df.to_csv('data/modified.tsv', sep='\t') #tab seperated

# %% [markdown]
# # To write to an excel file
# Before starting pip install xlwt openpyxl xlrd

# %%
india_df.to_excel('data/modified.xlsx')

# %%
test = pd.read_excel('data/modified.xlsx', index_col='Respondent')

# %%
test.head(10)
# Out:
#             Unnamed: 0                              MainBranch Hobbyist  \
# Respondent
# 8                    7             I code primarily as a hobby      Yes
# 10                   9          I am a developer by profession      Yes
# 15                  14  I am a student who is learning to code      Yes
# 50                  49          I am a developer by profession      Yes
# 65                  64          I am a developer by profession      Yes
# 68                  67          I am a developer by profession      Yes
# 75                  74          I am a developer by profession      Yes
# 78                  77          I am a developer by profession       No
# 83                  82          I am a developer by profession      Yes
# 89                  88  I am a student who is learning to code      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# ...

# %%
india_df.to_json('data/modified.json') # creates a dictionary kinda json

# %%
india_df.to_json('data/modified.json', orient='records', lines=True) #if we need the list like

# %%
test = pd.read_json('data/modified.json', orient='records', lines=True)
test.head(10)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           8             I code primarily as a hobby      Yes
# 1          10          I am a developer by profession      Yes
# 2          15  I am a student who is learning to code      Yes
# 3          50          I am a developer by profession      Yes
# 4          65          I am a developer by profession      Yes
# 5          68          I am a developer by profession      Yes
# 6          75          I am a developer by profession      Yes
# 7          78          I am a developer by profession       No
# 8          83          I am a developer by profession      Yes
# 9          89  I am a student who is learning to code      Yes
#
#                                          OpenSourcer  \
# 0                            Less than once per year
# 1                         Once a month or more often
# 2                                              Never
# 3                         Once a month or more often
# ...
